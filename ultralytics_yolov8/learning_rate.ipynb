# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
lr0=0.01
lrf=0.01
epochs=40
lf = lambda x: (1 - x / epochs) * (1.0 - lrf) + lrf
x = np.linspace(1, 40, 40)
y = lf(x)*lr0
lr0=0.001
y1 = lf(x)*lr0
#y[34:]
plt.ylim((0.00001,0.01))
plt.plot(x, y)
plt.plot(x, y1)
y
# Out:
# array([0.0097525, 0.009505 , 0.0092575, 0.00901  , 0.0087625, 0.008515 ,
#        0.0082675, 0.00802  , 0.0077725, 0.007525 , 0.0072775, 0.00703  ,
#        0.0067825, 0.006535 , 0.0062875, 0.00604  , 0.0057925, 0.005545 ,
#        0.0052975, 0.00505  , 0.0048025, 0.004555 , 0.0043075, 0.00406  ,
#        0.0038125, 0.003565 , 0.0033175, 0.00307  , 0.0028225, 0.002575 ,
#        0.0023275, 0.00208  , 0.0018325, 0.001585 , 0.0013375, 0.00109  ,
#        0.0008425, 0.000595 , 0.0003475, 0.0001   ])
